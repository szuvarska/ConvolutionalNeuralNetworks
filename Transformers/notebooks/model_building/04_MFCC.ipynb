# %%
import sys

sys.path.append("./../../src")


from Dataset_mfcc import SpeechCommandsDataset
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


from helper import evaluate, get_all_preds, plot_loss_and_accuracy
from Transformer import plot_confusion_matrix


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
test_dataset = SpeechCommandsDataset("./../../data/test", mode="modified")
train_dataset = SpeechCommandsDataset("./../../data/train", mode="modified")

# %%
class SpeechCommandCRNN(nn.Module):
    def __init__(self, num_classes=35):
        super(SpeechCommandCRNN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=(3, 3), padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=(3, 3), padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=(3, 3), padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
        )

        self.gru_input_size = 128 * (40 // 1)  # 40 is number of MFCC bins

        self.gru = nn.GRU(
            input_size=self.gru_input_size,
            hidden_size=128,
            num_layers=2,
            batch_first=True,
            bidirectional=True,
        )

        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(128 * 2, num_classes)

    def forward(self, x):
        x = self.conv(x)  # (batch, channels, freq, time)
        b, c, f, t = x.shape
        x = x.permute(0, 3, 1, 2)  # (batch, time, channels, freq)
        x = x.reshape(b, t, c * f)  # (batch, time, features)

        out, _ = self.gru(x)
        out = self.dropout(out[:, -1, :])
        out = self.fc(out)
        return out

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

model = SpeechCommandCRNN(num_classes=12).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20)

num_epochs = 20

train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for waveforms, labels in train_loader:
        waveforms, labels = waveforms.to(device), labels.to(device)

        outputs = model(waveforms)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    avg_loss = running_loss / total
    train_acc = correct / total
    train_losses.append(avg_loss)
    train_accuracies.append(train_acc)

    # Evaluate on test set
    test_acc, test_loss = evaluate(model, test_loader, device, silent=True)
    test_accuracies.append(test_acc)
    test_losses.append(test_loss)

    scheduler.step()

    print(f"Epoch {epoch+1} | Train Acc: {train_acc:.2%} | Test Acc: {test_acc:.2%}")
# Out:
# Epoch 1 | Train Acc: 81.12% | Test Acc: 91.41%
# Epoch 2 | Train Acc: 92.74% | Test Acc: 93.13%
# Epoch 3 | Train Acc: 94.58% | Test Acc: 94.31%
# Epoch 4 | Train Acc: 95.46% | Test Acc: 94.22%
# Epoch 5 | Train Acc: 96.11% | Test Acc: 95.60%
# Epoch 6 | Train Acc: 96.67% | Test Acc: 95.80%
# Epoch 7 | Train Acc: 97.02% | Test Acc: 95.96%
# Epoch 8 | Train Acc: 97.53% | Test Acc: 96.37%
# Epoch 9 | Train Acc: 97.89% | Test Acc: 96.09%
# Epoch 10 | Train Acc: 98.25% | Test Acc: 96.50%
# Epoch 11 | Train Acc: 98.52% | Test Acc: 96.59%
# Epoch 12 | Train Acc: 98.82% | Test Acc: 96.32%
# Epoch 13 | Train Acc: 99.01% | Test Acc: 96.26%
# Epoch 14 | Train Acc: 99.24% | Test Acc: 96.88%
# Epoch 15 | Train Acc: 99.33% | Test Acc: 96.94%
# Epoch 16 | Train Acc: 99.44% | Test Acc: 96.83%
# Epoch 17 | Train Acc: 99.51% | Test Acc: 96.87%
# Epoch 18 | Train Acc: 99.58% | Test Acc: 96.87%
# Epoch 19 | Train Acc: 99.64% | Test Acc: 96.90%
# Epoch 20 | Train Acc: 99.66% | Test Acc: 96.93%

# %%
plot_loss_and_accuracy(
    train_losses, test_losses, train_accuracies, test_accuracies, num_epochs
)

true_labels, pred_labels = get_all_preds(model, test_loader, device)

plot_confusion_matrix(true_labels, pred_labels, train_dataset, normalize=True)
# Out:
# <module 'matplotlib.pyplot' from '/home/aaa/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/transformer_venv/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
for i in range(5):
    evaluate(model, test_loader, device, silent=True)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=False,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
for i in range(5):
    evaluate(model, test_loader, device, silent=True)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
for i in range(5):
    evaluate(model, test_loader, device, silent=True)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=64,
    shuffle=False,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
for i in range(5):
    evaluate(model, test_loader, device, silent=True)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
for i in range(5):
    evaluate(model, test_loader, device, silent=True)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=256,
    shuffle=False,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
for i in range(5):
    evaluate(model, test_loader, device, silent=True)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=512,
    shuffle=False,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
for i in range(5):
    evaluate(model, test_loader, device, silent=True)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[15], line 10
#       1 test_loader = DataLoader(
#       2     test_dataset,
#       3     batch_size=512,
#    (...)      7     persistent_workers=True,
#       8 )
#       9 for i in range(5):
# ---> 10     evaluate(model, test_loader, device, silent=True)
#
# File ~/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/notebooks/model_building/../../src/helper.py:17, in evaluate(model, dataloader, device, silent)
#      15 for waveforms, labels in dataloader:
#      16     waveforms, labels = waveforms.to(device), labels.to(device)
# ---> 17     outputs = model(waveforms)
#      19     loss = criterion(outputs, labels)
#      20     total_loss += loss.item() * labels.size(0)
#
# File ~/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/transformer_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/transformer_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[3], line 36, in SpeechCommandCRNN.forward(self, x)
#      33 x = x.permute(0, 3, 1, 2)  # (batch, time, channels, freq)
#      34 x = x.reshape(b, t, c * f)  # (batch, time, features)
# ---> 36 out, _ = self.gru(x)
#      37 out = self.dropout(out[:, -1, :])
#      38 out = self.fc(out)
#
# File ~/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/transformer_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/transformer_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/transformer_venv/lib/python3.12/site-packages/torch/nn/modules/rnn.py:1393, in GRU.forward(self, input, hx)
#    1391 self.check_forward_args(input, hx, batch_sizes)
#    1392 if batch_sizes is None:
# -> 1393     result = _VF.gru(
#    1394         input,
#    1395         hx,
#    1396         self._flat_weights,  # type: ignore[arg-type]
#    1397         self.bias,
#    1398         self.num_layers,
#    1399         self.dropout,
#    1400         self.training,
#    1401         self.bidirectional,
#    1402         self.batch_first,
#    1403     )
#    1404 else:
#    1405     result = _VF.gru(
#    1406         input,
#    1407         batch_sizes,
#    (...)   1414         self.bidirectional,
#    1415     )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.63 GiB. GPU 0 has a total capacity of 11.69 GiB of which 314.31 MiB is free. Process 436805 has 1.15 GiB memory in use. Process 475523 has 5.41 GiB memory in use. Including non-PyTorch memory, this process has 3.37 GiB memory in use. Of the allocated memory 3.11 GiB is allocated by PyTorch, and 32.50 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)
test_loader = DataLoader(
    test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=12,
    pin_memory=True,
    persistent_workers=True,
)

model = SpeechCommandCRNN(num_classes=12).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20)

num_epochs = 20

train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for waveforms, labels in train_loader:
        waveforms, labels = waveforms.to(device), labels.to(device)

        outputs = model(waveforms)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    avg_loss = running_loss / total
    train_acc = correct / total
    train_losses.append(avg_loss)
    train_accuracies.append(train_acc)

    # Evaluate on test set
    test_acc, test_loss = evaluate(model, test_loader, device, silent=True)
    test_accuracies.append(test_acc)
    test_losses.append(test_loss)

    scheduler.step()

    print(f"Epoch {epoch+1} | Train Acc: {train_acc:.2%} | Test Acc: {test_acc:.2%}")
# Out:
# Epoch 1 | Train Acc: 81.42% | Test Acc: 89.02%
# Epoch 2 | Train Acc: 92.83% | Test Acc: 92.99%
# Epoch 3 | Train Acc: 94.89% | Test Acc: 95.23%
# Epoch 4 | Train Acc: 95.80% | Test Acc: 95.68%
# Epoch 5 | Train Acc: 96.41% | Test Acc: 94.99%
# Epoch 6 | Train Acc: 96.80% | Test Acc: 95.56%
# Epoch 7 | Train Acc: 97.35% | Test Acc: 96.16%
# Epoch 8 | Train Acc: 97.76% | Test Acc: 96.69%
# Epoch 9 | Train Acc: 98.14% | Test Acc: 96.90%
# Epoch 10 | Train Acc: 98.38% | Test Acc: 96.64%
# Epoch 11 | Train Acc: 98.61% | Test Acc: 96.74%
# Epoch 12 | Train Acc: 98.93% | Test Acc: 96.84%
# Epoch 13 | Train Acc: 99.10% | Test Acc: 97.01%
# Epoch 14 | Train Acc: 99.26% | Test Acc: 96.46%
# Epoch 15 | Train Acc: 99.41% | Test Acc: 96.93%
# Epoch 16 | Train Acc: 99.49% | Test Acc: 96.88%
# Epoch 17 | Train Acc: 99.57% | Test Acc: 96.94%
# Epoch 18 | Train Acc: 99.63% | Test Acc: 96.94%
# Epoch 19 | Train Acc: 99.69% | Test Acc: 96.91%
# Epoch 20 | Train Acc: 99.72% | Test Acc: 96.93%

# %%
plot_loss_and_accuracy(
    train_losses, test_losses, train_accuracies, test_accuracies, num_epochs
)

true_labels, pred_labels = get_all_preds(model, test_loader, device)

plot_confusion_matrix(true_labels, pred_labels, train_dataset, normalize=True)
# Out:
# <module 'matplotlib.pyplot' from '/home/aaa/Desktop/deep_learning/ConvolutionalNeuralNeutworks/Transformers/transformer_venv/lib/python3.12/site-packages/matplotlib/pyplot.py'>
